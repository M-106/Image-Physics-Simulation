# %% [markdown]
# # Efficient ISM Parameters

# %% [markdown]
# ### Imports

# %%
import sys
sys.path += [".."] # os.path.abspath("../img-phy-sim")

import img_phy_sim as ips
from img_phy_sim.data import PhysGenDataset, get_image

import os
import random

import numpy as np
from torch.utils.data import DataLoader

# %% [markdown]
# ### Data

# %%
# get image
input_, output_ = get_image(mode='train', variation="sound_reflection", input_type="osm", output_type="complex_only", 
               shuffle=False, return_output=True, as_numpy_array=True)

# %%
output_.max()

# %%
ips.img.imshow(input_, size=4)

# %%
ips.img.imshow(output_, size=4)

# %% [markdown]
# ### Parameter Tests

# %%
reflection_map = ips.ism.compute_reflection_map(
    source_rel=(0.5, 0.5),
    img=input_,
    wall_values=[0],   
    wall_thickness=1,
    max_order=1,
    step_px=1
)

ips.img.imshow(ips.ism.reflection_map_to_img(reflection_map), size=5)
ips.eval.calc_metrices(ips.ism.reflection_map_to_img(reflection_map), output_, rays_format_is_image=True, should_print=True);

# %%
reflection_map = ips.ism.compute_reflection_map(
    source_rel=(0.5, 0.5),
    img=input_,
    wall_values=[0],   
    wall_thickness=1,
    max_order=1,
    step_px=2,
    parallelization=-1
)

ips.img.imshow(ips.ism.reflection_map_to_img(reflection_map), size=5)
ips.eval.calc_metrices(ips.ism.reflection_map_to_img(reflection_map), output_, rays_format_is_image=True, should_print=True);

# %%
reflection_map = ips.ism.compute_reflection_map(
    source_rel=(0.5, 0.5),
    img=input_,
    wall_values=[0],   
    wall_thickness=1,
    max_order=1,
    step_px=4,
    parallelization=-1
)

ips.img.imshow(ips.ism.reflection_map_to_img(reflection_map), size=5)
ips.eval.calc_metrices(ips.ism.reflection_map_to_img(reflection_map), output_, rays_format_is_image=True, should_print=True);

# %%
reflection_map = ips.ism.compute_reflection_map(
    source_rel=(0.5, 0.5),
    img=input_,
    wall_values=[0],   
    wall_thickness=2,
    max_order=1,
    step_px=1,
    parallelization=-1
)

ips.img.imshow(ips.ism.reflection_map_to_img(reflection_map), size=5)
ips.eval.calc_metrices(ips.ism.reflection_map_to_img(reflection_map), output_, rays_format_is_image=True, should_print=True);

# %%
reflection_map = ips.ism.compute_reflection_map(
    source_rel=(0.5, 0.5),
    img=input_,
    wall_values=[0],   
    wall_thickness=5,
    max_order=1,
    step_px=1,
    parallelization=-1
)

ips.img.imshow(ips.ism.reflection_map_to_img(reflection_map), size=5)
ips.eval.calc_metrices(ips.ism.reflection_map_to_img(reflection_map), output_, rays_format_is_image=True, should_print=True);

# %%
reflection_map = ips.ism.compute_reflection_map(
    source_rel=(0.5, 0.5),
    img=input_,
    wall_values=[0],   
    wall_thickness=1,
    max_order=1,
    ignore_zero_order=True,
    step_px=1,
    parallelization=-1
)

ips.img.imshow(ips.ism.reflection_map_to_img(reflection_map), size=5)
ips.eval.calc_metrices(ips.ism.reflection_map_to_img(reflection_map), output_, rays_format_is_image=True, should_print=True);
